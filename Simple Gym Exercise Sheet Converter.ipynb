# %% [markdown]
# # Simple Gym Exercise Sheet Converter - From XLSX to TXT for Smartwatch Notes
# Notebook for a quick conversion of my gym exercises sheets from XLS to TXT, to make the importation on Goggle Keep quickly.

# %% [markdown]
# ## Selection of the XLSX File and of the Sheet

# %% [markdown]
# Specify the XLSX file path:

# %%
file_path = "./Palestra Scheda Forza Legs _ Push _ Pull.xlsx"

# %% [markdown]
# Select the sheet that you want to use:

# %%
sheet_name = "6 Days - Block 1"

# %% [markdown]
# ## Customisation Options
# In this section you can specify some simple customisation options for the output text:

# %% [markdown]
# #### Specify how many blank lines you want between each row:

# %%
number_of_blank_rows = 1

# %% [markdown]
# #### Selection of the bullet list dot type:

# %% [markdown]
# **Note**: tested only with ASCII characters. It could probably work with UTF-8 and emojis.

# %%
bullet_dot = ">"

# %% [markdown]
# #### Selection of the item separator

# %%
item_separator = "|"

# %% [markdown]
# ## File Importation and Conversion

# %%
import pandas as pd
import numpy as nan
import pyperclip

df_scheda_xls = pd.read_excel(io=file_path, sheet_name=sheet_name, dtype=str)

# %% [markdown]
# Here you can check the imported XLSX to be sure that the data types are correct:

# %%
df_scheda_xls
# Out:
#                     DAY & EXERCISE  WARM-UP SETS  WORKING SETS   REPS    %1RM  \
# 0                              NaN           NaN           NaN    NaN     NaN
# 1                           LEGS 1  WARM-UP SETS  WORKING SETS   REPS    %1RM
# 2                       BACK SQUAT             4             3      5  75-80%
# 3                       BACK SQUAT             0             2      8     72%
# 4                 GLUTE HAM RAISES             0             3  12-15     NaN
# 5                       HACK SQUAT             1             3     12     NaN
# 6                    HIP ABDUCTION             0             3  15-20     NaN
# 7                         LEG CURL             1             3  10-12     NaN
# 8               SEATED CALF RAISES             1             3  12-15     NaN
# 9                              ABS             0             5    NaN     NaN
# 10                             NaN           NaN           NaN    NaN     NaN
# 11                          PUSH 1  WARM-UP SETS  WORKING SETS   REPS    %1RM
# 12                     BENCH PRESS             4             1      3  82-87%
# 13                     BENCH PRESS             3             2    6-8     80%
# 14  DUMBBELL SEATED SHOULDER PRESS             2             3  12-15     NaN
# 15                    WEIGHTED DIP             1             3  10-12     NaN
# 16          DUMBBELL SKULL CRUSHER             1             3  12-15     NaN
# 17          DUMBBELL LATERAL RAISE             1             3  12-15     NaN
# 18                             NaN           NaN           NaN    NaN     NaN
# 19                          PULL 1  WARM-UP SETS  WORKING SETS   REPS    %1RM
# 20          WIDE-GRIP LAT PULLDOWN             2             4    6-8     NaN
# 21                SEATED CABLE ROW             1             3  10-12     NaN
# 22               DUMMBELL PULLOVER             2             3  12-15     NaN
# 23                   BAYESIAN CURL             1             3  12-15     NaN
# 24          INCLIINE DUMBBELL CURL             0             3  12-15     NaN
# 25                  DUMBBELL SHRUG             1             3  15-20     NaN
# 26                             NaN           NaN           NaN    NaN     NaN
# 27                          LEGS 2  WARM-UP SETS  WORKING SETS   REPS    %1RM
# 28                        DEADLIFT             3             3    3-4  85-90%
# 29                   45° LEG PRESS             2             3  10-12     NaN
# 30                        LEG CURL             1             3  12-15     NaN
# 31            STANDING CALF RAISES             1             3  12-15     NaN
# 32                   LEG EXTENSION             0             3    6-8     NaN
# 33                             ABS             0             0    NaN     NaN
# 34                             NaN           NaN           NaN    NaN     NaN
# 35                          PUSH 2  WARM-UP SETS  WORKING SETS   REPS    %1RM
# 36          CLOSE-GRIP BENCH PRESS             2             3      5     NaN
# 37          BARBELL OVERHEAD PRESS             2             3      5     NaN
# 38          INCLINE DUMBBELL PRESS             1             3  12-15     NaN
# 39                    PEC DECK FLY             0             3  12-15     NaN
# 40        TRICEPS PUSH DOWN (ROPE)             1             3  12-15     NaN
# 41          EGYPTIAN LATERAL RAISE             1             3  15-20     NaN
# 42                             NaN           NaN           NaN    NaN     NaN
# 43                          PULL 2  WARM-UP SETS  WORKING SETS   REPS    %1RM
# 44             CHEST SUPPORTED ROW             2             3    6-8     NaN
# 45       NEUTRAL GRIP LAT PULLDOWN             2             3  10-12     NaN
# 46                       HELMS ROW             1             3  12-15     NaN
# 47                     HUMMER CURL             1             3  12-15     NaN
# 48       EZ BAR CURL (SCOTT BENCH)             0             4  10-12     NaN
# 49                       FACE PULL             0             3  15-20     NaN
# 50                             NaN           NaN           NaN    NaN     NaN
# 51              MANDATORY REST DAY           NaN           NaN    NaN     NaN
#
#     RPE     REST               NOTES
# 0   NaN      NaN                 NaN
# 1   RPE     REST               NOTES
# 2     9  4-5 MIN                 NaN
# 3   NaN  2-3 MIN                 NaN
# 4     8  1-2 MIN                 NaN
# 5     9  2-3 MIN                 NaN
# 6     8  1-2 MIN                 NaN
# 7     9  1-2 MIN                 NaN
# 8     8  1-2 MIN                 NaN
# 9   NaN  1-2 MIN  EXERCISE OF CHOICE
# 10  NaN      NaN                 NaN
# 11  RPE     REST               NOTES
# 12    9  4-5 MIN                 NaN
# 13  NaN  2-3 MIN                 NaN
# 14    8  1-2 MIN                 NaN
# 15    8  2-3 MIN                 NaN
# 16    8  1-2 MIN                 NaN
# 17    8  1-2 MIN                 NaN
# 18  NaN      NaN                 NaN
# 19  RPE     REST               NOTES
# 20    9  2-3 MIN                 NaN
# 21    9  2-3 MIN                 NaN
# 22    8  1-2 MIN                 NaN
# 23    8  1-2 MIN                 NaN
# 24    8  1-2 MIN                 NaN
# 25    7  1-2 MIN                 NaN
# 26  NaN      NaN                 NaN
# 27  RPE     REST               NOTES
# 28    9  4-5 MIN                 NaN
# 29    8  2-3 MIN                 NaN
# 30    9  1-2 MIN                 NaN
# 31    8  1-2 MIN                 NaN
# 32    9  1-2 MIN                 NaN
# 33    7  1-2 MIN  EXERCISE OF CHOICE
# 34  NaN      NaN                 NaN
# 35  RPE     REST               NOTES
# 36    8  2-3 MIN                 NaN
# 37    8  2-3 MIN                 NaN
# 38    8  2-3 MIN                 NaN
# 39    9  1-2 MIN                 NaN
# 40    9  1-2 MIN                 NaN
# 41    8  1-2 MIN                 NaN
# 42  NaN      NaN                 NaN
# 43  RPE     REST               NOTES
# 44    9  2-3 MIN                 NaN
# 45    9  2-3 MIN                 NaN
# 46    8  1-2 MIN                 NaN
# 47    8  1-2 MIN                 NaN
# 48    9  1-2 MIN                 NaN
# 49    8  1-2 MIN                 NaN
# 50  NaN      NaN                 NaN
# 51  NaN      NaN                 NaN

# %% [markdown]
# #### Conversion

# %%
out_text = ""
next_row_is_a_new_day = False

assert number_of_blank_rows >= 0

for xls_index, xls_row in df_scheda_xls.iterrows():

    # Check if we reached the end of a day
    if pd.isnull(xls_row['DAY & EXERCISE']):
        next_row_is_a_new_day = True

        if out_text.__len__() != 0: # We have already inserted something
            out_text += '\n'
        
        continue

    # we reached the header row of a day
    if not pd.isnull(xls_row['DAY & EXERCISE']) and next_row_is_a_new_day:
        next_row_is_a_new_day = False
        out_text += '_____' + xls_row['DAY & EXERCISE'] + '_____'
        
    else:
        # we're reading an exercise roe
        out_text += bullet_dot + ' ' + str(xls_row['DAY & EXERCISE']) + ': (' + str(xls_row['WARM-UP SETS']) + ') ' + str(xls_row['WORKING SETS'])
        
        # I didn't specify them for some exercises
        if not pd.isnull(xls_row['REPS']):
            out_text += '*' + str(xls_row['REPS'])

        # I didn't specify them for some exercises
        if not pd.isnull(xls_row['REPS']):
            out_text += ' ' + item_separator + ' RPE ' + str(xls_row['RPE'])

        # I didn't specify them for some exercises
        if not pd.isnull(xls_row['%1RM']):
            out_text += ' ' + item_separator + ' %1RM ' + str(xls_row['%1RM'])

        out_text += ' ' + item_separator + ' Rest ' + str(xls_row['REST']).lower()

    # Adding the blank lines
    for i in range(0, number_of_blank_rows + 1):
        out_text += '\n'

print(out_text)
# Out:
# _____LEGS 1_____
#
# > BACK SQUAT: (4) 3*5 | RPE 9 | %1RM75-80% | Rest 4-5 min
#
# > BACK SQUAT: (0) 2*8 | RPE nan | %1RM72% | Rest 2-3 min
#
# > GLUTE HAM RAISES: (0) 3*12-15 | RPE 8 | Rest 1-2 min
#
# > HACK SQUAT: (1) 3*12 | RPE 9 | Rest 2-3 min
#
# > HIP ABDUCTION: (0) 3*15-20 | RPE 8 | Rest 1-2 min
#
# > LEG CURL: (1) 3*10-12 | RPE 9 | Rest 1-2 min
#
# > SEATED CALF RAISES: (1) 3*12-15 | RPE 8 | Rest 1-2 min
#
# > ABS: (0) 5 | Rest 1-2 min
#
#
# _____PUSH 1_____
#
# > BENCH PRESS: (4) 1*3 | RPE 9 | %1RM82-87% | Rest 4-5 min
#
# > BENCH PRESS: (3) 2*6-8 | RPE nan | %1RM80% | Rest 2-3 min
#
# > DUMBBELL SEATED SHOULDER PRESS: (2) 3*12-15 | RPE 8 | Rest 1-2 min
#
# > WEIGHTED DIP: (1) 3*10-12 | RPE 8 | Rest 2-3 min
#
# > DUMBBELL SKULL CRUSHER: (1) 3*12-15 | RPE 8 | Rest 1-2 min
#
# > DUMBBELL LATERAL RAISE: (1) 3*12-15 | RPE 8 | Rest 1-2 min
#
#
# _____PULL 1_____
#
# > WIDE-GRIP LAT PULLDOWN: (2) 4*6-8 | RPE 9 | Rest 2-3 min
#
# > SEATED CABLE ROW: (1) 3*10-12 | RPE 9 | Rest 2-3 min
#
# > DUMMBELL PULLOVER: (2) 3*12-15 | RPE 8 | Rest 1-2 min
#
# > BAYESIAN CURL: (1) 3*12-15 | RPE 8 | Rest 1-2 min
#
# > INCLIINE DUMBBELL CURL: (0) 3*12-15 | RPE 8 | Rest 1-2 min
#
# > DUMBBELL SHRUG: (1) 3*15-20 | RPE 7 | Rest 1-2 min
#
#
# _____LEGS 2_____
#
# > DEADLIFT: (3) 3*3-4 | RPE 9 | %1RM85-90% | Rest 4-5 min
#
# > 45° LEG PRESS: (2) 3*10-12 | RPE 8 | Rest 2-3 min
#
# > LEG CURL: (1) 3*12-15 | RPE 9 | Rest 1-2 min
#
# > STANDING CALF RAISES: (1) 3*12-15 | RPE 8 | Rest 1-2 min
#
# > LEG EXTENSION: (0) 3*6-8 | RPE 9 | Rest 1-2 min
#
# > ABS: (0) 0 | Rest 1-2 min
#
#
# _____PUSH 2_____
#
# > CLOSE-GRIP BENCH PRESS: (2) 3*5 | RPE 8 | Rest 2-3 min
#
# > BARBELL OVERHEAD PRESS: (2) 3*5 | RPE 8 | Rest 2-3 min
#
# > INCLINE DUMBBELL PRESS: (1) 3*12-15 | RPE 8 | Rest 2-3 min
#
# > PEC DECK FLY: (0) 3*12-15 | RPE 9 | Rest 1-2 min
#
# > TRICEPS PUSH DOWN (ROPE): (1) 3*12-15 | RPE 9 | Rest 1-2 min
#
# > EGYPTIAN LATERAL RAISE: (1) 3*15-20 | RPE 8 | Rest 1-2 min
#
#
# _____PULL 2_____
#
# > CHEST SUPPORTED ROW: (2) 3*6-8 | RPE 9 | Rest 2-3 min
#
# > NEUTRAL GRIP LAT PULLDOWN: (2) 3*10-12 | RPE 9 | Rest 2-3 min
#
# > HELMS ROW: (1) 3*12-15 | RPE 8 | Rest 1-2 min
#
# > HUMMER CURL: (1) 3*12-15 | RPE 8 | Rest 1-2 min
#
# > EZ BAR CURL (SCOTT BENCH): (0) 4*10-12 | RPE 9 | Rest 1-2 min
#
# > FACE PULL: (0) 3*15-20 | RPE 8 | Rest 1-2 min
#
#
# _____MANDATORY REST DAY_____

# %% [markdown]
# ## Copying the Result in the Clipboard!

# %%
pyperclip.copy(out_text)
print("Result copied in the clipboard. Enjoy!")
# Out:
# Result copied in the clipboard. Enjoy!
